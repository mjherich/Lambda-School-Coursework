# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('max_colwidth', 4000)

# %%
api_key = ''

# %%
from apiclient.discovery import build

# %%
youtube = build('youtube', 'v3', developerKey=api_key)

# %%
type(youtube)
# Out:
# googleapiclient.discovery.Resource

# %%
topic_id_categories = ['/m/03glg', '/m/07c1v', '/m/09s1f', '/m/01k8wb']

# %%
req = youtube.search().list(q='sk learn tutorial', part='snippet', videoEmbeddable='true', type='video', topicId=topic_id_categories, maxResults=50)
req1 = youtube.search().list(q='learn scikit learn', part='snippet', videoEmbeddable='true', type='video', topicId=topic_id_categories, maxResults=50)
req2 = youtube.search().list(q='coding with scikit learn', part='snippet', videoEmbeddable='true', type='video', topicId=topic_id_categories, maxResults=50)
req3 = youtube.search().list(q='sk learn tutorial', part='snippet', videoEmbeddable='true', type='video', topicId=topic_id_categories, maxResults=50)
req4 = youtube.search().list(q='machine learning in scikit learn', part='snippet', videoEmbeddable='true', type='video', topicId=topic_id_categories, maxResults=50)
req5 = youtube.search().list(q='javascript', part='snippet', videoEmbeddable='true', type='video', topicId=topic_id_categories, maxResults=50)
req6 = youtube.search().list(q='javascript oop', part='snippet', videoEmbeddable='true', type='video', topicId=topic_id_categories, maxResults=50)
req7 = youtube.search().list(q='javascript classes', part='snippet', videoEmbeddable='true', type='video', topicId=topic_id_categories, maxResults=50)
req8 = youtube.search().list(q='programming in javascript', part='snippet', videoEmbeddable='true', type='video', topicId=topic_id_categories, maxResults=50)
req8 = youtube.search().list(q='react', part='snippet', videoEmbeddable='true', type='video', topicId=topic_id_categories, maxResults=50)
req9 = youtube.search().list(q='learn react', part='snippet', videoEmbeddable='true', type='video', topicId=topic_id_categories, maxResults=50)
req10 = youtube.search().list(q='react tutorials', part='snippet', videoEmbeddable='true', type='video', topicId=topic_id_categories, maxResults=50)
req11 = youtube.search().list(q='coding with react', part='snippet', videoEmbeddable='true', type='video', topicId=topic_id_categories, maxResults=50)
req12 = youtube.search().list(q='react programming', part='snippet', videoEmbeddable='true', type='video', topicId=topic_id_categories, maxResults=50)
req13 = youtube.search().list(q='LESS', part='snippet', videoEmbeddable='true', type='video', topicId=topic_id_categories, maxResults=50)
req14 = youtube.search().list(q='learn LESS', part='snippet', videoEmbeddable='true', type='video', topicId=topic_id_categories, maxResults=50)
req15 = youtube.search().list(q='coding in LESS', part='snippet', videoEmbeddable='true', type='video', topicId=topic_id_categories, maxResults=50)
req16 = youtube.search().list(q='LESS tutorial', part='snippet', videoEmbeddable='true', type='video', topicId=topic_id_categories, maxResults=50)
req17 = youtube.search().list(q='LESS programming', part='snippet', videoEmbeddable='true', type='video', topicId=topic_id_categories, maxResults=50)
req16 = youtube.search().list(q='python development', part='snippet', videoEmbeddable='true', type='video', topicId=topic_id_categories, maxResults=50)
req17 = youtube.search().list(q='programming in javascript', part='snippet', videoEmbeddable='true', type='video', topicId=topic_id_categories, maxResults=50)
req18 = youtube.search().list(q='python OOP', part='snippet', videoEmbeddable='true', type='video', topicId=topic_id_categories, maxResults=50)
req19 = youtube.search().list(q='python classes', part='snippet', videoEmbeddable='true', type='video', topicId=topic_id_categories, maxResults=50)
req20 = youtube.search().list(q='programming in python', part='snippet', videoEmbeddable='true', type='video', topicId=topic_id_categories, maxResults=50)
req21 = youtube.search().list(q='python tutorial', part='snippet', videoEmbeddable='true', type='video', topicId=topic_id_categories, maxResults=50)
req22 = youtube.search().list(q='pandas in python', part='snippet', videoEmbeddable='true', type='video', topicId=topic_id_categories, maxResults=50)
req23 = youtube.search().list(q='data engineering pandas', part='snippet', videoEmbeddable='true', type='video', topicId=topic_id_categories, maxResults=50)
req24 = youtube.search().list(q='data visualization for data science', part='snippet', videoEmbeddable='true', type='video', topicId=topic_id_categories, maxResults=50)
req25 = youtube.search().list(q='visualization libraries for data science', part='snippet', videoEmbeddable='true', type='video', topicId=topic_id_categories, maxResults=50)
req26 = youtube.search().list(q='pandas dataframes', part='snippet', videoEmbeddable='true', type='video', topicId=topic_id_categories, maxResults=50)

# %%
type(req)
# Out:
# googleapiclient.http.HttpRequest

# %%
res = req.execute()
res1 = req1.execute()
res2 = req2.execute()
res3 = req3.execute()
res4 = req4.execute()
res5 = req5.execute()
res6 = req6.execute()
res7 = req7.execute()
res8 = req8.execute()
res9 = req9.execute()
res10 = req10.execute()
res11 = req11.execute()
res12 = req12.execute()
res13 = req13.execute()
res14 = req14.execute()
res15 = req15.execute()
res16 = req16.execute()
res17 = req17.execute()
res18 = req18.execute()
res19 = req19.execute()
res20 = req20.execute()
res21 = req21.execute()
res22 = req22.execute()
res23 = req23.execute()
res24 = req24.execute()
res25 = req25.execute()
res26 = req26.execute()

# %%
len(res['items'])
# Out:
# 50

# %%
df_0 = pd.DataFrame(res['items'])
df_1 = pd.DataFrame(res1['items'])
df_2 = pd.DataFrame(res2['items'])
df_3 = pd.DataFrame(res3['items'])
df_4 = pd.DataFrame(res4['items'])
df_5 = pd.DataFrame(res5['items'])
df_6 = pd.DataFrame(res6['items'])
df_7 = pd.DataFrame(res7['items'])
df_8 = pd.DataFrame(res8['items'])
df_9 = pd.DataFrame(res9['items'])
df_10 = pd.DataFrame(res10['items'])
df_11 = pd.DataFrame(res11['items'])
df_12 = pd.DataFrame(res12['items'])
df_13 = pd.DataFrame(res13['items'])
df_14 = pd.DataFrame(res14['items'])
df_15 = pd.DataFrame(res15['items'])
df_16 = pd.DataFrame(res16['items'])
df_17 = pd.DataFrame(res17['items'])
df_18 = pd.DataFrame(res18['items'])
df_19 = pd.DataFrame(res19['items'])
df_20 = pd.DataFrame(res20['items'])
df_21 = pd.DataFrame(res21['items'])
df_22 = pd.DataFrame(res22['items'])
df_23 = pd.DataFrame(res23['items'])
df_24 = pd.DataFrame(res24['items'])
df_25 = pd.DataFrame(res25['items'])
df_26 = pd.DataFrame(res26['items'])

# %%
res
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': '"Bdx4f4ps3xCOOo1WZ91nTLkRZ_c/BfkUgtTSWeQb7KBqK3yMNgPrJSw"',
#  'nextPageToken': 'CDIQAA',
#  'regionCode': 'US',
#  'pageInfo': {'totalResults': 1000000, 'resultsPerPage': 50},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': '"Bdx4f4ps3xCOOo1WZ91nTLkRZ_c/TGJRr5MCMtthv50Pxs2LWpS2mmk"',
#    'id': {'kind': 'youtube#video', 'videoId': '0Lt9w-BxKFQ'},
#    'snippet': {'publishedAt': '2018-12-07T06:43:39.000Z',
#     'channelId': 'UCsvqVGtbbyHaMoevxPAq9Fg',
#     'title': 'Scikit-Learn Tutorial | Machine Learning With Scikit-Learn | Sklearn | Python Tutorial | Simplilearn',
#     'description': 'This Scikit-learn tutorial will help you understand what is Scikit-learn, what can we achieve using Scikit-learn and a demo on how to use Scikit-learn in Python.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/0Lt9w-BxKFQ/default.jpg',
#       'width': 120,
#       'height': 90},
# ...

# %%
df_0
# Out:
#                                                          etag  \
# 0   "Bdx4f4ps3xCOOo1WZ91nTLkRZ_c/TGJRr5MCMtthv50Pxs2LWpS2mmk"
# 1   "Bdx4f4ps3xCOOo1WZ91nTLkRZ_c/-tv_wK5FhkM-pdSyeG5JUURm8cM"
# 2   "Bdx4f4ps3xCOOo1WZ91nTLkRZ_c/AzxSYKguiUYLAwfAb8mzzAQTHy4"
# 3   "Bdx4f4ps3xCOOo1WZ91nTLkRZ_c/-OGyTpJWr79rNsD3rvQZPT4XTLs"
# 4   "Bdx4f4ps3xCOOo1WZ91nTLkRZ_c/TDAENGTNGuh66KqxWln2ldcOslY"
# 5   "Bdx4f4ps3xCOOo1WZ91nTLkRZ_c/X1eALlA2XWpR-wjv4hM7rRjkoQ8"
# 6   "Bdx4f4ps3xCOOo1WZ91nTLkRZ_c/kugx2PMNZpS6sQrNRmxChNhf7T0"
# 7   "Bdx4f4ps3xCOOo1WZ91nTLkRZ_c/Tw0ALvHrQf7sWg_vP6wMqtHoFvs"
# 8   "Bdx4f4ps3xCOOo1WZ91nTLkRZ_c/_mqO6kQq_LQabEtibBCKX-5YCZg"
# 9   "Bdx4f4ps3xCOOo1WZ91nTLkRZ_c/vn8CXJD9b0yGXDxdKneSYwK4ol0"
# 10  "Bdx4f4ps3xCOOo1WZ91nTLkRZ_c/GT0ZzSkSEHGamqQevQpGAwl7-nk"
# 11  "Bdx4f4ps3xCOOo1WZ91nTLkRZ_c/lUE5f0stg0V-Aie-lbZtj32zlrk"
# 12  "Bdx4f4ps3xCOOo1WZ91nTLkRZ_c/MS7SOU_5KWm1x7pLlmsBf-vnG9o"
# 13  "Bdx4f4ps3xCOOo1WZ91nTLkRZ_c/zuiJes8fm0wnCWMM6ixrKb1fjxE"
# ...

# %%
df_0.id.head()
# Out:
# 0    {'kind': 'youtube#video', 'videoId': '0Lt9w-BxKFQ'}
# 1    {'kind': 'youtube#video', 'videoId': 'bwZ3Qiuj3i8'}
# 2    {'kind': 'youtube#video', 'videoId': 'rvVkVsG49uU'}
# 3    {'kind': 'youtube#video', 'videoId': 'KTeVOb8gaD4'}
# 4    {'kind': 'youtube#video', 'videoId': '4PXAztQtoTg'}
# Name: id, dtype: object

# %%
df_0.snippet.head()
# Out:
# 0    {'publishedAt': '2018-12-07T06:43:39.000Z', 'channelId': 'UCsvqVGtbbyHaMoevxPAq9Fg', 'title': 'Scikit-Learn Tutorial | Machine Learning With Scikit-Learn | Sklearn | Python Tutorial | Simplilearn', 'description': 'This Scikit-learn tutorial will help you understand what is Scikit-learn, what can we achieve using Scikit-learn and a demo on how to use Scikit-learn in Python.', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/0Lt9w-BxKFQ/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/0Lt9w-BxKFQ/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/0Lt9w-BxKFQ/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'Simplilearn', 'liveBroadcastContent': 'none'}
# ...

# %%
for item in res['items']:
    print(item['id']['videoId']) #prints all of the ids from the 1st query
# Out:
# 0Lt9w-BxKFQ
# bwZ3Qiuj3i8
# rvVkVsG49uU
# KTeVOb8gaD4
# 4PXAztQtoTg
# -BQCB6Uch1g
# uSjgTFdEbSY
# 80fZrVMurPM
# BFaadIqWlAg
# FG3W1_8ogBE
# JTj-WgWLKFM
# EvV99YhSsJU
# VsLYdjiG5KQ
# 81ZGOib7DTk
# 2bW5RzzjzMA
# xP9wr4kPwg8
# 7wWMP2elSvE
# RZYjsw6P4nI
# RlQuVL6-qe8
# L_dQrZZjGDg
# URdnFlZnlaE
# SBYdqlLgbGk
# gK43gtGh49o
# URTZ2jKCgBc
# BlaNvgfrHDg
# BJ5ARpYYI-c
# uTDVPET8P24
# 1nWFHa6K23w
# ikt0sny_ImY
# WRaKnFB3SYQ
# aCdg-d_476Y
# O3qXimMGn28
# QdBy02ExhGI
# IsXXlYVBt1M
# EvnpoUTXA0E
# npdSRTg5aaE
# AEMz9VgTgS4
# a60yeHZCeqw
# kApPBm1YsqU
# dNBvQ38MlT8
# d0nEJptpu6k
# Gol_qOgRqfA
# bPYJi1E9xeM
# MaKLWy5zXe8
# ZueoXMgCd1c
# erfZsVZbGJI
# IsRRvEoIQ4k
# x9pIM2GkbF4
# JthgChPKFG4
# 99MN-rl8jGY

# %%
union_all_queries = pd.concat([df_0, df_1, df_2, df_3, df_4, df_5,
                               df_6, df_7, df_8, df_9, df_10,
                               df_11,df_12, df_13, df_14, df_15, 
                               df_16, df_17, df_18, df_19, df_20,
                               df_21, df_22, df_23, df_24, df_25,
                               df_26])

# %%
union_all_queries.shape
# Out:
# (1350, 4)

# %%
union_all_queries.snippet.head()
# Out:
# 0    {'publishedAt': '2018-12-07T06:43:39.000Z', 'channelId': 'UCsvqVGtbbyHaMoevxPAq9Fg', 'title': 'Scikit-Learn Tutorial | Machine Learning With Scikit-Learn | Sklearn | Python Tutorial | Simplilearn', 'description': 'This Scikit-learn tutorial will help you understand what is Scikit-learn, what can we achieve using Scikit-learn and a demo on how to use Scikit-learn in Python.', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/0Lt9w-BxKFQ/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/0Lt9w-BxKFQ/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/0Lt9w-BxKFQ/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'Simplilearn', 'liveBroadcastContent': 'none'}
# ...

# %%
ytu = pd.DataFrame(union_all_queries)

# %%
ytu.head()
# Out:
#                                                         etag  \
# 0  "Bdx4f4ps3xCOOo1WZ91nTLkRZ_c/TGJRr5MCMtthv50Pxs2LWpS2mmk"
# 1  "Bdx4f4ps3xCOOo1WZ91nTLkRZ_c/-tv_wK5FhkM-pdSyeG5JUURm8cM"
# 2  "Bdx4f4ps3xCOOo1WZ91nTLkRZ_c/AzxSYKguiUYLAwfAb8mzzAQTHy4"
# 3  "Bdx4f4ps3xCOOo1WZ91nTLkRZ_c/-OGyTpJWr79rNsD3rvQZPT4XTLs"
# 4  "Bdx4f4ps3xCOOo1WZ91nTLkRZ_c/TDAENGTNGuh66KqxWln2ldcOslY"
#
#                                                     id                  kind  \
# 0  {'kind': 'youtube#video', 'videoId': '0Lt9w-BxKFQ'}  youtube#searchResult
# 1  {'kind': 'youtube#video', 'videoId': 'bwZ3Qiuj3i8'}  youtube#searchResult
# 2  {'kind': 'youtube#video', 'videoId': 'rvVkVsG49uU'}  youtube#searchResult
# 3  {'kind': 'youtube#video', 'videoId': 'KTeVOb8gaD4'}  youtube#searchResult
# 4  {'kind': 'youtube#video', 'videoId': '4PXAztQtoTg'}  youtube#searchResult
#
# ...

# %%
ytu.id.head()
# Out:
# 0    {'kind': 'youtube#video', 'videoId': '0Lt9w-BxKFQ'}
# 1    {'kind': 'youtube#video', 'videoId': 'bwZ3Qiuj3i8'}
# 2    {'kind': 'youtube#video', 'videoId': 'rvVkVsG49uU'}
# 3    {'kind': 'youtube#video', 'videoId': 'KTeVOb8gaD4'}
# 4    {'kind': 'youtube#video', 'videoId': '4PXAztQtoTg'}
# Name: id, dtype: object

# %%
from pandas.io.json import json_normalize

ytu_id = json_normalize(ytu['id']) 
ytu_id.head()
# Out:
#             kind      videoId
# 0  youtube#video  0Lt9w-BxKFQ
# 1  youtube#video  bwZ3Qiuj3i8
# 2  youtube#video  rvVkVsG49uU
# 3  youtube#video  KTeVOb8gaD4
# 4  youtube#video  4PXAztQtoTg

# %%
ytu_snip = json_normalize(ytu['snippet'])

ytu_snip.head()
# Out:
#                   channelId           channelTitle  \
# 0  UCsvqVGtbbyHaMoevxPAq9Fg            Simplilearn
# 1  UCkw4JCwteGrDHIsyIIKo4tQ               edureka!
# 2  UCJS9pqu9BzkAMNTmzNMNhvg  Google Cloud Platform
# 3  UCfzlCWGWYyIQ0aLC5w48gBQ                sentdex
# 4  UCkhm72fuzkS9fYGlGpEmj7A              Enthought
#
#                                                                                                                                                                description  \
# 0        This Scikit-learn tutorial will help you understand what is Scikit-learn, what can we achieve using Scikit-learn and a demo on how to use Scikit-learn in Python.
# 1      Python Certification Training for Data Science : https://www.edureka.co/python This Edureka video on "Scikit-learn Tutorial" introduces you to machine learning ...
# ...

# %%
ytu_snip.columns
# Out:
# Index(['channelId', 'channelTitle', 'description', 'liveBroadcastContent',
#        'publishedAt', 'thumbnails.default.height', 'thumbnails.default.url',
#        'thumbnails.default.width', 'thumbnails.high.height',
#        'thumbnails.high.url', 'thumbnails.high.width',
#        'thumbnails.medium.height', 'thumbnails.medium.url',
#        'thumbnails.medium.width', 'title'],
#       dtype='object')

# %%
ytu_snip = ytu_snip.drop(columns=['channelId', 'liveBroadcastContent',
                                  'thumbnails.default.height', 'thumbnails.default.url',
                                  'thumbnails.default.width', 'thumbnails.high.height',
                                  'thumbnails.high.url', 'thumbnails.high.width',
                                  'thumbnails.medium.height', 'thumbnails.medium.url',
                                  'thumbnails.medium.width'])

# %%
ytu_snip.head()
# Out:
#             channelTitle  \
# 0            Simplilearn
# 1               edureka!
# 2  Google Cloud Platform
# 3                sentdex
# 4              Enthought
#
#                                                                                                                                                                description  \
# 0        This Scikit-learn tutorial will help you understand what is Scikit-learn, what can we achieve using Scikit-learn and a demo on how to use Scikit-learn in Python.
# 1      Python Certification Training for Data Science : https://www.edureka.co/python This Edureka video on "Scikit-learn Tutorial" introduces you to machine learning ...
# 2      Scikit-learn is a well-documented and well-loved Python machine learning library. The library is maintained and reliable, offering a vast collection of machine ...
# ...

# %%
ytu_snip.shape
# Out:
# (1350, 4)

# %%
ytu_id.shape
# Out:
# (1350, 2)

# %%
ytu_id = ytu_id.drop(columns=['kind'])

ytu_id.head()
# Out:
#        videoId
# 0  0Lt9w-BxKFQ
# 1  bwZ3Qiuj3i8
# 2  rvVkVsG49uU
# 3  KTeVOb8gaD4
# 4  4PXAztQtoTg

# %%
ytu = pd.concat([ytu_id, ytu_snip], axis=1)

# %%
ytu.head()
# Out:
#        videoId           channelTitle  \
# 0  0Lt9w-BxKFQ            Simplilearn
# 1  bwZ3Qiuj3i8               edureka!
# 2  rvVkVsG49uU  Google Cloud Platform
# 3  KTeVOb8gaD4                sentdex
# 4  4PXAztQtoTg              Enthought
#
#                                                                                                                                                                description  \
# 0        This Scikit-learn tutorial will help you understand what is Scikit-learn, what can we achieve using Scikit-learn and a demo on how to use Scikit-learn in Python.
# 1      Python Certification Training for Data Science : https://www.edureka.co/python This Edureka video on "Scikit-learn Tutorial" introduces you to machine learning ...
# 2      Scikit-learn is a well-documented and well-loved Python machine learning library. The library is maintained and reliable, offering a vast collection of machine ...
# ...

# %%
ytu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1350 entries, 0 to 1349
# Data columns (total 5 columns):
# videoId         1350 non-null object
# channelTitle    1350 non-null object
# description     1350 non-null object
# publishedAt     1350 non-null object
# title           1350 non-null object
# dtypes: object(5)
# memory usage: 52.8+ KB

# %%
# !pip install --user squarify

# %%
"""
Import Statements
"""

# Base
from collections import Counter
import re

import pandas as pd

# Plotting
import matplotlib.pyplot as plt
import seaborn as sns

# NLP Libraries
import spacy
from spacy.tokenizer import Tokenizer
from nltk.stem import PorterStemmer

import nltk
nltk.download('punkt')
nltk.download('stopwords')
from nltk.tokenize import sent_tokenize # Sentence Tokenizer
from nltk.tokenize import word_tokenize # Word Tokenizer
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.probability import FreqDist

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
from gensim import corpora

from gensim.models.ldamulticore import LdaMulticore

nlp = spacy.load("en_core_web_lg")
# Out:
# [nltk_data] Downloading package punkt to /home/seek/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/seek/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# How can we count the raw text?
ytu['description'].value_counts(normalize=True)[:50]
# Out:
# Visit my personal web-page for the Python code: http://www.brunel.ac.uk/~csstnns.                                                                                             0.010370
#                                                                                                                                                                               0.009630
# Facebook - https://www.facebook.com/TheNewBoston-464114846956315/ GitHub - https://github.com/buckyroberts Google+ ...                                                        0.008889
# Python Tutorial to learn Python programming with examples Complete Python Tutorial for Beginners Playlist ...                                                                 0.005926
# In this machine learning series I will work on the Wisconsin Breast Cancer dataset that comes with scikit-learn. I will train a few algorithms and evaluate their ...         0.005185
# ...

# %%
ytu_desc = ytu['description']

# %%
# Based on "The Unreasonable Effectiveness of RNN" implementation
import numpy as np

chars = list(set(ytu_desc)) # split and remove duplicate characters. convert to list.

num_chars = len(chars) # the number of unique characters
txt_data_size = len(ytu_desc)

print("unique characters : ", num_chars)
print("txt_data_size : ", txt_data_size)
# Out:
# unique characters :  1004
# txt_data_size :  1350

# %%
# one hot encode
char_to_int = dict((c, i) for i, c in enumerate(chars)) # "enumerate" retruns index and value. Convert it to dictionary
int_to_char = dict((i, c) for i, c in enumerate(chars))
print(char_to_int)
print("----------------------------------------------------")
print(int_to_char)
print("----------------------------------------------------")
# integer encode input data
integer_encoded = [char_to_int[i] for i in article_text] # "integer_encoded" is a list which has a sequence converted from an original data to integers.
print(integer_encoded)
print("----------------------------------------------------")
print("data length : ", len(integer_encoded))
# Out:
# {'': 0, 'Python es uno de los lenguajes de programación más importantes actualmente, siendo un lenguaje de proposito general puedes llegar a crear con el ...': 1, 'Massive Christmas in July Sale // 35% OFF + Free Shipping: https://rosegoldandblack.com/pages/carlo-ople For an EXTRA 15% off, use code: CHRISJULY15 at ...': 2, 'After following an introductory course of machine learning on Coursera and working with data scientists on commercial projects I wanted to apply ML to ...': 3, 'React vs Angular vs Vue: What is the best JavaScript framework in 2019? This video answers your questions. Get my Complete React Course with a big ...': 4, 'Our Leader - https://www.youtube.com/user/technothepig My Links: ✦ My SMP Server : play.ocsmp.club (opens saturday) ✦ Discord ...': 5, "Aaron Krauss will be giving an introduction to game development using plain JavaScript, meaning no libraries or plugins. He'll be live-coding a single-player ...": 6, 'Classes and objects in javascript Link to my progr
# ...

# %%
# hyperparameters

iteration = 1000
sequence_length = 40
batch_size = round((txt_data_size /sequence_length)+0.5) # = math.ceil
hidden_size = 500  # size of hidden layer of neurons.  
learning_rate = 1e-1


# model parameters

W_xh = np.random.randn(hidden_size, num_chars)*0.01     # weight input -> hidden. 
W_hh = np.random.randn(hidden_size, hidden_size)*0.01   # weight hidden -> hidden
W_hy = np.random.randn(num_chars, hidden_size)*0.01     # weight hidden -> output

b_h = np.zeros((hidden_size, 1)) # hidden bias
b_y = np.zeros((num_chars, 1)) # output bias

h_prev = np.zeros((hidden_size,1)) # h_(t-1)

# %%
def forwardprop(inputs, targets, h_prev):
    
    """
    The forward prop pass in our example creates a log proba for each character in a sequence
    
    "ABCDEFG"
    
    """
        
    # Since the RNN receives the sequence, the weights are not updated during one sequence.
    xs, hs, ys, ps = {}, {}, {}, {} # dictionary
    hs[-1] = np.copy(h_prev) # Copy previous hidden state vector to -1 key value.
    loss = 0 # loss initialization
    
    for t in range(len(inputs)): # t is a "time step" and is used as a key(dic).  
        
        xs[t] = np.zeros((num_chars,1)) 
        xs[t][inputs[t]] = 1
        hs[t] = np.tanh(np.dot(W_xh, xs[t]) + np.dot(W_hh, hs[t-1]) + b_h) # hidden state. 
        ys[t] = np.dot(W_hy, hs[t]) + b_y # unnormalized log probabilities for next chars
        ps[t] = np.exp(ys[t]) / np.sum(np.exp(ys[t])) # probabilities for next chars. 
        
        # Softmax. -> The sum of probabilities is 1 even without the exp() function, but all of the elements are positive through the exp() function.
        loss += -np.log(ps[t][targets[t],0]) # softmax (cross-entropy loss). Efficient and simple code

#         y_class = np.zeros((num_chars, 1)) 
#         y_class[targets[t]] =1
#         loss += np.sum(y_class*(-np.log(ps[t]))) # softmax (cross-entropy loss)        

    return loss, ps, hs, xs

# %%
def backprop(ps, inputs, hs, xs, targets):

    dWxh, dWhh, dWhy = np.zeros_like(W_xh), np.zeros_like(W_hh), np.zeros_like(W_hy) # make all zero matrices.
    dbh, dby = np.zeros_like(b_h), np.zeros_like(b_y)
    dhnext = np.zeros_like(hs[0]) # (hidden_size,1) 

    # reversed
    for t in reversed(range(len(inputs))):
        dy = np.copy(ps[t]) # shape (num_chars,1).  "dy" means "dloss/dy"
        dy[targets[t]] -= 1 # backprop into y. After taking the soft max in the input vector, subtract 1 from the value of the element corresponding to the correct label.
        dWhy += np.dot(dy, hs[t].T)
        dby += dy 
        dh = np.dot(W_hy.T, dy) + dhnext # backprop into h. 
        dhraw = (1 - hs[t] * hs[t]) * dh # backprop through tanh nonlinearity #tanh'(x) = 1-tanh^2(x)
        dbh += dhraw
        dWxh += np.dot(dhraw, xs[t].T)
        dWhh += np.dot(dhraw, hs[t-1].T)
        dhnext = np.dot(W_hh.T, dhraw)
    for dparam in [dWxh, dWhh, dWhy, dbh, dby]: 
        np.clip(dparam, -5, 5, out=dparam) # clip to mitigate exploding gradients.  
    
    return dWxh, dWhh, dWhy, dbh, dby

# %%
# %%time

data_pointer = 0

# memory variables for Adagrad
mWxh, mWhh, mWhy = np.zeros_like(W_xh), np.zeros_like(W_hh), np.zeros_like(W_hy)
mbh, mby = np.zeros_like(b_h), np.zeros_like(b_y) 

for i in range(iteration):
    h_prev = np.zeros((hidden_size,1)) # reset RNN memory
    data_pointer = 0 # go from start of data
    
    for b in range(batch_size):
        
        inputs = [char_to_int[ch] for ch in ytu_desc[data_pointer:data_pointer+sequence_length]]
        targets = [char_to_int[ch] for ch in ytu_desc[data_pointer+1:data_pointer+sequence_length+1]] # t+1        
            
        if (data_pointer+sequence_length+1 >= len(ytu_desc) and b == batch_size-1): # processing of the last part of the input data. 
#             targets.append(char_to_int[txt_data[0]])   # When the data doesn't fit, add the first char to the back.
            targets.append(char_to_int[''])   # When the data doesn't fit, add space(" ") to the back.


        # forward
        loss, ps, hs, xs = forwardprop(inputs, targets, h_prev)
#         print(loss)
    
        # backward
        dWxh, dWhh, dWhy, dbh, dby = backprop(ps, inputs, hs, xs, targets) 
        
        
    # perform parameter update with Adagrad
        for param, dparam, mem in zip([W_xh, W_hh, W_hy, b_h, b_y], 
                                    [dWxh, dWhh, dWhy, dbh, dby], 
                                    [mWxh, mWhh, mWhy, mbh, mby]):
            mem += dparam * dparam # elementwise
            param += -learning_rate * dparam / np.sqrt(mem + 1e-8) # adagrad update      
    
        data_pointer += sequence_length # move data pointer
        
    if i % 100 == 0:
        print ('iter %d, loss: %f' % (i, loss)) # print progress
# Out:
# iter 0, loss: 1979.375246
# iter 100, loss: 131.371121
# iter 200, loss: 99.681579
# iter 300, loss: 52.423281
# iter 400, loss: 23.950352
# iter 500, loss: 11.468705
# iter 600, loss: 6.701296
# iter 700, loss: 4.541539
# iter 800, loss: 3.329871
# iter 900, loss: 2.508246
# CPU times: user 4h 44min 46s, sys: 2min 44s, total: 4h 47min 31s
# Wall time: 47min 58s

# %%
predict('', 15)
# Out:
# ----
# ...
